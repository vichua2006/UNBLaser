# %% [markdown]
# <a href="https://colab.research.google.com/github/cristianramirezrodriguez/UNBLaser/blob/main/2D_Image_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2D Image Analysis

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')

#Load the image
image = Image.open('exp200.tiff')

# Convert the image to a NumPy array
image_array = np.array(image)

# Get the image dimensions
height, width = image_array.shape

# Create x and y position arrays
x = np.arange(width)
y = np.arange(height)
xv, yv = np.meshgrid(x, y)

# Flatten the arrays
x_pos = xv.flatten()
y_pos = yv.flatten()
brightness = image_array.flatten()

plt.figure()
plt.scatter(x_pos, y_pos, c=brightness, cmap='gray', s=1)
plt.colorbar()

plt.figure()
plt.scatter(x_pos, brightness)

plt.figure()
plt.scatter(y_pos, brightness)
plt.show()

# %%
fig = plt.figure(figsize=(7.0, 4.0), constrained_layout=True)
gs  = fig.add_gridspec(ncols=2, nrows=2)
# This time, let the top plot axis spans both columns:
ax0  = fig.add_subplot(gs[0,1])
ax10 = fig.add_subplot(gs[1,0])
ax11 = fig.add_subplot(gs[1,1])
# Create a 1D numpy array for all figure Axes:
axs = np.array([ax0, ax10, ax11])

# Populate each axis with plots:
x = np.linspace(-np.pi, np.pi, num=101)
axs[0].scatter(x_pos, y_pos, c=brightness, cmap='gray', s=1)
axs[1].scatter(x_pos, brightness, label='brightness as a function of x coordinate')
axs[2].plot(y_pos, brightness, label='brightness as a function of y coordinate')

# Set x-labels on botom row only:
axs[1].set_xlabel('x  (pixels)')
axs[2].set_xlabel('y  (pixels)')
# Set y-labels on left column only:
axs[1].set_ylabel('brightness')

for ax in axs:
	ax.legend()
	ax.grid()

# Show the entire figure:
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
